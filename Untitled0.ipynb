# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

# %%
fed_df = pd.read_csv("gdpxpercapdata.csv")
print(fed_df.to_markdown())
df_cleaned = fed_df.dropna()
# Out:
# |       | Country or Area                                      |   Year | Item                         |       Value |
# |------:|:-----------------------------------------------------|-------:|:-----------------------------|------------:|
# |     0 | Afghanistan                                          |   2022 | Gross Domestic Product (GDP) |    344.649  |
# |     1 | Afghanistan                                          |   2021 | Gross Domestic Product (GDP) |    378.083  |
# |     2 | Afghanistan                                          |   2020 | Gross Domestic Product (GDP) |    512.75   |
# |     3 | Afghanistan                                          |   2019 | Gross Domestic Product (GDP) |    512.91   |
# |     4 | Afghanistan                                          |   2018 | Gross Domestic Product (GDP) |    513.981  |
# |     5 | Afghanistan                                          |   2017 | Gross Domestic Product (GDP) |    534.02   |
# ...

# %%
df_pivot = df_cleaned.pivot(index='Year', columns='Country or Area', values='Value')

# Plotting the line graph
plt.figure(figsize=(12, 8))
for country in df_pivot.columns:
    plt.plot(df_pivot.index, df_pivot[country], label=country)

plt.title('GDP Over Time by Country')
plt.xlabel('Year')
plt.ylabel('GDP')
plt.grid(True)
plt.tight_layout()
plt.show()
